# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
hourly = pd.read_csv("C:/Users/HP/Desktop/pharma_sales_hourly.csv")
daily = pd.read_csv("C:/Users/HP/Desktop/Pharma_sales_daily.csv")
weekly = pd.read_csv("C:/Users/HP/Desktop/pharma_sales_weekly.csv")
monthly = pd.read_csv("C:/Users/HP/Desktop/pharma_sales_monthly.csv")

print("HOURLY:", hourly.shape)
print("DAILY:", daily.shape)
print("WEEKLY:", weekly.shape)
print("MONTHLY:", monthly.shape)

print("\nHOURLY COLUMNS:")
print(hourly.columns.tolist())

print("\nDAILY COLUMNS:")
print(daily.columns.tolist())

print("\nWEEKLY COLUMNS:")
print(weekly.columns.tolist())

print("\nMONTHLY COLUMNS:")
print(monthly.columns.tolist())
# Out:
# HOURLY: (50532, 13)
# DAILY: (2106, 13)
# WEEKLY: (302, 9)
# MONTHLY: (70, 9)
#
# HOURLY COLUMNS:
# ['datum', 'M01AB', 'M01AE', 'N02BA', 'N02BE', 'N05B', 'N05C', 'R03', 'R06', 'Year', 'Month', 'Hour', 'Weekday Name']
#
# DAILY COLUMNS:
# ['datum', 'M01AB', 'M01AE', 'N02BA', 'N02BE', 'N05B', 'N05C', 'R03', 'R06', 'Year', 'Month', 'Hour', 'Weekday Name']
#
# WEEKLY COLUMNS:
# ['datum', 'M01AB', 'M01AE', 'N02BA', 'N02BE', 'N05B', 'N05C', 'R03', 'R06']
#
# MONTHLY COLUMNS:
# ['datum', 'M01AB', 'M01AE', 'N02BA', 'N02BE', 'N05B', 'N05C', 'R03', 'R06']

# %%
hourly.head(4)
# Out:
#               datum  M01AB  M01AE  N02BA  N02BE  N05B  N05C  R03  R06  Year  \
# 0  01-02-2014 08:00    0.0   0.67    0.4    2.0   0.0   0.0  0.0  1.0  2014
# 1  01-02-2014 09:00    0.0   0.00    1.0    0.0   2.0   0.0  0.0  0.0  2014
# 2  01-02-2014 10:00    0.0   0.00    0.0    3.0   2.0   0.0  0.0  0.0  2014
# 3  01-02-2014 11:00    0.0   0.00    0.0    2.0   1.0   0.0  0.0  0.0  2014
#
#    Month  Hour Weekday Name
# 0      1     8     Thursday
# 1      1     9     Thursday
# 2      1    10     Thursday
# 3      1    11     Thursday

# %%
hourly.shape
# Out:
# (50532, 13)

# %%
hourly.columns
# Out:
# Index(['datum', 'M01AB', 'M01AE', 'N02BA', 'N02BE', 'N05B', 'N05C', 'R03',
#        'R06', 'Year', 'Month', 'Hour', 'Weekday Name'],
#       dtype='str')

# %%
daily.head()
# Out:
#         datum  M01AB  M01AE  N02BA  N02BE  N05B  N05C   R03  R06  Year  Month  \
# 0  01-02-2014    0.0   3.67    3.4  32.40   7.0   0.0   0.0  2.0  2014      1
# 1  01-03-2014    8.0   4.00    4.4  50.60  16.0   0.0  20.0  4.0  2014      1
# 2  01-04-2014    2.0   1.00    6.5  61.85  10.0   0.0   9.0  1.0  2014      1
# 3  01-05-2014    4.0   3.00    7.0  41.10   8.0   0.0   3.0  0.0  2014      1
# 4  01-06-2014    5.0   1.00    4.5  21.70  16.0   2.0   6.0  2.0  2014      1
#
#    Hour Weekday Name
# 0   248     Thursday
# 1   276       Friday
# 2   276     Saturday
# 3   276       Sunday
# 4   276       Monday

# %%
daily.shape
# Out:
# (2106, 13)

# %%
weekly.head()
# Out:
#         datum  M01AB  M01AE  N02BA   N02BE  N05B  N05C   R03   R06
# 0  01-05-2014  14.00  11.67   21.3  185.95  41.0   0.0  32.0   7.0
# 1  01-12-2014  29.33  12.68   37.9  190.70  88.0   5.0  21.0   7.2
# 2   1/19/2014  30.67  26.34   45.9  218.40  80.0   8.0  29.0  12.0
# 3   1/26/2014  34.00  32.37   31.5  179.60  80.0   8.0  23.0  10.0
# 4  02-02-2014  31.02  23.35   20.7  159.88  84.0  12.0  29.0  12.0

# %%
weekly.shape
# Out:
# (302, 9)

# %%
monthly.shape
# Out:
# (70, 9)

# %%
## Checking Data Types

# %%
print("HOURLY")
print(hourly.dtypes)

print("\nDAILY")
print(daily.dtypes)

print("\nWEEKLY")
print(weekly.dtypes)

print("\nMONTHLY")
print(monthly.dtypes)
# Out:
# HOURLY
# datum               str
# M01AB           float64
# M01AE           float64
# N02BA           float64
# N02BE           float64
# N05B            float64
# N05C            float64
# R03             float64
# R06             float64
# Year              int64
# Month             int64
# Hour              int64
# Weekday Name        str
# dtype: object
#
# DAILY
# datum               str
# M01AB           float64
# M01AE           float64
# N02BA           float64
# N02BE           float64
# N05B            float64
# N05C            float64
# R03             float64
# R06             float64
# Year              int64
# Month             int64
# Hour              int64
# Weekday Name        str
# dtype: object
#
# WEEKLY
# datum        str
# M01AB    float64
# M01AE    float64
# N02BA    float64
# N02BE    float64
# N05B     float64
# N05C     float64
# R03      float64
# R06      float64
# dtype: object
#
# MONTHLY
# datum        str
# M01AB    float64
# M01AE    float64
# N02BA    float64
# N02BE    float64
# N05B     float64
# N05C       int64
# R03      float64
# R06      float64
# dtype: object

# %%
## Checking Missing Values

# %%
print("HOURLY MISSING VALUES")
print(hourly.isnull().sum())

print("\nDAILY MISSING VALUES")
print(daily.isnull().sum())

print("\nWEEKLY MISSING VALUES")
print(weekly.isnull().sum())

print("\nMONTHLY MISSING VALUES")
print(monthly.isnull().sum())
# Out:
# HOURLY MISSING VALUES
# datum           0
# M01AB           0
# M01AE           0
# N02BA           0
# N02BE           0
# N05B            0
# N05C            0
# R03             0
# R06             0
# Year            0
# Month           0
# Hour            0
# Weekday Name    0
# dtype: int64
#
# DAILY MISSING VALUES
# datum           0
# M01AB           0
# M01AE           0
# N02BA           0
# N02BE           0
# N05B            0
# N05C            0
# R03             0
# R06             0
# Year            0
# Month           0
# Hour            0
# Weekday Name    0
# dtype: int64
#
# WEEKLY MISSING VALUES
# datum    0
# M01AB    0
# M01AE    0
# N02BA    0
# N02BE    0
# N05B     0
# N05C     0
# R03      0
# R06      0
# dtype: int64
#
# MONTHLY MISSING VALUES
# datum    0
# M01AB    0
# M01AE    0
# N02BA    0
# N02BE    0
# N05B     0
# N05C     0
# R03      0
# R06      0
# dtype: int64

# %%
## Checking Duplicates

# %%
print("Hourly duplicate dates:", hourly["datum"].duplicated().sum())
print("Daily duplicate dates:", daily["datum"].duplicated().sum())
print("Weekly duplicate dates:", weekly["datum"].duplicated().sum())
print("Monthly duplicate dates:", monthly["datum"].duplicated().sum())
# Out:
# Hourly duplicate dates: 0
# Daily duplicate dates: 0
# Weekly duplicate dates: 0
# Monthly duplicate dates: 0

# %%
## Coverting Dates from str to datetime

# %%
hourly["datum"] = pd.to_datetime(hourly["datum"], format="mixed")
daily["datum"] = pd.to_datetime(daily["datum"], format="mixed")
weekly["datum"] = pd.to_datetime(weekly["datum"], format="mixed")
monthly["datum"] = pd.to_datetime(monthly["datum"], format="mixed")

# %%
print("Hourly:", hourly["datum"].dtype)
print("Daily:", daily["datum"].dtype)
print("Weekly:", weekly["datum"].dtype)
print("Monthly:", monthly["datum"].dtype)
# Out:
# Hourly: datetime64[us]
# Daily: datetime64[us]
# Weekly: datetime64[us]
# Monthly: datetime64[us]

# %%
print(hourly["datum"].min(), hourly["datum"].max())
print(daily["datum"].min(), daily["datum"].max())
print(weekly["datum"].min(), weekly["datum"].max())
print(monthly["datum"].min(), monthly["datum"].max())
# Out:
# 2014-01-02 08:00:00 2019-10-08 19:00:00
# 2014-01-02 00:00:00 2019-10-08 00:00:00
# 2014-01-05 00:00:00 2019-10-13 00:00:00
# 2014-01-31 00:00:00 2019-10-31 00:00:00

# %%
drug_cols = [
    "M01AB",
    "M01AE",
    "N02BA",
    "N02BE",
    "N05B",
    "N05C",
    "R03",
    "R06"
]

daily["total_demand"] = daily[drug_cols].sum(axis=1)

print(daily.columns.tolist())
# Out:
# ['datum', 'M01AB', 'M01AE', 'N02BA', 'N02BE', 'N05B', 'N05C', 'R03', 'R06', 'Year', 'Month', 'Hour', 'Weekday Name', 'total_demand']

# %%
daily[drug_cols].describe().T
# Out:
#         count       mean        std  min    25%    50%     75%         max
# M01AB  2106.0   5.033683   2.737579  0.0   3.00   4.99   6.670   17.340000
# M01AE  2106.0   3.895830   2.133337  0.0   2.34   3.67   5.138   14.463000
# N02BA  2106.0   3.880441   2.384010  0.0   2.00   3.50   5.200   16.000000
# N02BE  2106.0  29.917095  15.590966  0.0  19.00  26.90  38.300  161.000000
# N05B   2106.0   8.853627   5.605605  0.0   5.00   8.00  12.000   54.833333
# N05C   2106.0   0.593522   1.092988  0.0   0.00   0.00   1.000    9.000000
# R03    2106.0   5.512262   6.428736  0.0   1.00   4.00   8.000   45.000000
# R06    2106.0   2.900198   2.415816  0.0   1.00   2.00   4.000   15.000000

# %%
daily[["datum", "total_demand"]].head(10)
# Out:
#         datum  total_demand
# 0  01-02-2014         48.47
# 1  01-03-2014        107.00
# 2  01-04-2014         91.35
# 3  01-05-2014         66.10
# 4  01-06-2014         58.20
# 5  01-07-2014          0.00
# 6  01-08-2014         75.23
# 7  01-09-2014         62.68
# 8  01-10-2014         81.30
# 9  01-11-2014         87.24

# %%
daily["total_demand"].describe()
# Out:
# count    2106.000000
# mean       60.586659
# std        21.561684
# min         0.000000
# 25%        46.446750
# 50%        58.466500
# 75%        72.814250
# max       198.950000
# Name: total_demand, dtype: float64

# %%
daily["rolling_30"] = (
    daily["total_demand"]
    .rolling(window=30)
    .mean()
)
daily["rolling_30"]
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 2101    63.855389
# 2102    64.023722
# 2103    64.865056
# 2104    65.419956
# 2105    65.945389
# Name: rolling_30, Length: 2106, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))

plt.plot(
    daily["datum"],
    daily["total_demand"],
    alpha=0.3,
    label="Daily Demand"
)

plt.plot(
    daily["datum"],
    daily["rolling_30"],
    linewidth=2,
    label="30-Day Rolling Average"
)

plt.title("Total Pharmaceutical Demand with 30-Day Rolling Average")
plt.xlabel("Date")
plt.ylabel("Demand")
plt.legend()

plt.show()

# %%
daily.describe()
# Out:
#              M01AB        M01AE        N02BA        N02BE         N05B  \
# count  2106.000000  2106.000000  2106.000000  2106.000000  2106.000000
# mean      5.033683     3.895830     3.880441    29.917095     8.853627
# std       2.737579     2.133337     2.384010    15.590966     5.605605
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       3.000000     2.340000     2.000000    19.000000     5.000000
# 50%       4.990000     3.670000     3.500000    26.900000     8.000000
# 75%       6.670000     5.138000     5.200000    38.300000    12.000000
# max      17.340000    14.463000    16.000000   161.000000    54.833333
#
#               N05C          R03          R06         Year        Month  \
# count  2106.000000  2106.000000  2106.000000  2106.000000  2106.000000
# mean      0.593522     5.512262     2.900198  2016.401235     6.344255
# std       1.092988     6.428736     2.415816     1.665060     3.386954
# min       0.000000     0.000000     0.000000  2014.000000     1.000000
# 25%       0.000000     1.000000     1.000000  2015.000000     3.000000
# 50%       0.000000     4.000000     2.000000  2016.000000     6.000000
# 75%       1.000000     8.000000     4.000000  2018.000000     9.000000
# max       9.000000    45.000000    15.000000  2019.000000    12.000000
#
#               Hour  total_demand
# count  2106.000000   2106.000000
# mean    275.945869     60.586659
# std       1.970547     21.561684
# min     190.000000      0.000000
# 25%     276.000000     46.446750
# 50%     276.000000     58.466500
# 75%     276.000000     72.814250
# max     276.000000    198.950000

# %%
## SEASONALITY ANALYSIS

# %% [markdown]
# # Monthly

# %%
Monthly_Seasonality = (
    daily.groupby("Month")["total_demand"].mean())
print(Monthly_Seasonality)
# Out:
# Month
# 1     75.517249
# 2     68.666086
# 3     61.094651
# 4     56.937322
# 5     53.365418
# 6     49.960339
# 7     47.088728
# 8     48.589308
# 9     61.115870
# 10    73.932667
# 11    63.562556
# 12    71.656213
# Name: total_demand, dtype: float64

# %%
plt.figure(figsize=(10, 5))

plt.plot(
    Monthly_Seasonality.index,
    Monthly_Seasonality.values,
    marker="o"
)

plt.title("Average Daily Pharmaceutical Demand by Month")
plt.xlabel("Month")
plt.ylabel("Average Daily Demand")
plt.xticks(range(1, 13))

plt.show()

# %% [markdown]
# # Weekday

# %%
Weekday_demand = (
    daily.groupby("Weekday Name")["total_demand"].mean()
        .reindex([
            "Monday",
        "Tuesday",
        "Wednesday",
        "Thursday",
        "Friday",
        "Saturday",
        "Sunday"
    ])
)

print(Weekday_demand)
# Out:
# Weekday Name
# Monday       60.607364
# Tuesday      60.017432
# Wednesday    59.238425
# Thursday     57.184018
# Friday       60.247480
# Saturday     65.673071
# Sunday       61.134343
# Name: total_demand, dtype: float64

# %%
plt.figure(figsize=(10, 5))

plt.bar(
    Weekday_demand.index,
    Weekday_demand.values
)

plt.title("Average Pharmaceutical Demand by Day of Week")
plt.xlabel("Day of Week")
plt.ylabel("Average Daily Demand")

plt.xticks(rotation=30)

plt.show()

# %% [markdown]
# ## Hourly

# %%
## Create total hourly demand

# %%
hourly["total demand"] = hourly[drug_cols].sum(axis=1)

# %%
hourly["total demand"]
# Out:
# 0         4.07
# 1         3.00
# 2         5.00
# 3         3.00
# 4         9.00
#          ...
# 50527    12.70
# 50528     3.33
# 50529     4.00
# 50530     9.00
# 50531    10.33
# Name: total demand, Length: 50532, dtype: float64

# %%
## average demand by hour

# %%
hourly_by_time = (
    hourly.groupby("Hour")["total demand"]
    .mean()
)

print(hourly_by_time)
# Out:
# Hour
# 0     0.000000
# 1     0.000000
# 2     0.000000
# 3     0.000000
# 4     0.000000
# 5     0.000000
# 6     0.000000
# 7     0.272004
# 8     2.868352
# 9     3.843552
# 10    4.554328
# 11    5.096845
# 12    5.007699
# 13    4.545759
# 14    4.169361
# 15    3.887425
# 16    3.728370
# 17    3.919423
# 18    4.782325
# 19    5.375953
# 20    5.325920
# 21    3.137042
# 22    0.076209
# 23    0.000277
# Name: total demand, dtype: float64

# %%
plt.figure(figsize=(12, 5))

plt.plot(
    hourly_by_time.index,
    hourly_by_time.values,
    marker="o"
)

plt.title("Average Pharmaceutical Demand by Hour")
plt.xlabel("Hour of Day")
plt.ylabel("Average Total Demand")

plt.xticks(range(24))
plt.grid(True)

plt.show()

# %% [markdown]
# ## Validating the time-series structure

# %%
## Checking for missing dates

# %%
daily = daily.sort_values("datum").reset_index(drop = True)

# %%
daily
# Out:
#            datum     M01AB    M01AE   N02BA   N02BE  N05B   N05C    R03  \
# 0     01-01-2015   0.00000  0.00000  0.0000   0.000  0.00  0.000   0.00
# 1     01-01-2016   0.00000  0.00000  0.0000   0.000  0.00  0.000   0.00
# 2     01-01-2017   3.54375  3.95625  1.5625  25.675  8.75  1.875   6.25
# 3     01-01-2018   0.00000  0.00000  0.0000   0.000  0.00  0.000   0.00
# 4     01-01-2019   0.00000  0.00000  0.0000   0.000  0.00  0.000   0.00
# ...          ...       ...      ...     ...     ...   ...    ...    ...
# 2101   9/30/2015   5.32000  4.33000  4.0000  22.500  9.00  0.000   0.00
# 2102   9/30/2016   7.00000  5.00000  2.6000  23.400  5.00  0.000  10.00
# 2103   9/30/2017   5.33000  3.01000  3.0000  61.900  6.00  0.000  28.00
# 2104   9/30/2018  11.01000  2.01000  2.0000  54.000  9.00  1.000   3.00
# 2105   9/30/2019   2.00000  1.43900  2.1000  49.400  9.00  0.000   5.00
#
#         R06  Year  Month  Hour Weekday Name  total_demand  rolling_30
# 0     0.000  2015      1   276     Thursday        0.0000   65.730500
# 1     0.000  2016      1   276       Friday        0.0000   71.729567
# 2     0.625  2017      1   276       Sunday       52.2375   82.783250
# 3     0.000  2018      1   276       Monday        0.0000   59.507100
# 4     0.000  2019      1   276      Tuesday        0.0000   67.935200
# ...     ...   ...    ...   ...          ...           ...         ...
# 2101  1.000  2015      9   276    Wednesday       46.1500   55.978900
# 2102  3.000  2016      9   276       Friday       56.0000   68.329233
# 2103  0.000  2017      9   276     Saturday      107.2400   55.361367
# 2104  3.000  2018      9   276       Sunday       85.0200   66.045800
# 2105  2.000  2019      9   276       Monday       70.9390   60.826789
#
# [2106 rows x 15 columns]

# %%
print(daily["datum"].dtype)
# Out:
# datetime64[us]

# %%
daily["datum"] = pd.to_datetime(
    daily["datum"],
    format="mixed"
)

# %%
date_diff = daily["datum"].diff().dt.days

print(date_diff.value_counts().sort_index())
# Out:
# datum
# 1.0    2105
# Name: count, dtype: int64

# %%
print(daily[["datum", "total_demand"]].head(15))
# Out:
#         datum  total_demand
# 0  2014-01-02         48.47
# 1  2014-01-03        107.00
# 2  2014-01-04         91.35
# 3  2014-01-05         66.10
# 4  2014-01-06         58.20
# 5  2014-01-07          0.00
# 6  2014-01-08         75.23
# 7  2014-01-09         62.68
# 8  2014-01-10         81.30
# 9  2014-01-11         87.24
# 10 2014-01-12         27.16
# 11 2014-01-13         90.20
# 12 2014-01-14         62.33
# 13 2014-01-15         58.04
# 14 2014-01-16         65.60

# %%
print(daily[["datum", "total_demand"]].tail(15))
# Out:
#           datum  total_demand
# 2091 2019-09-24     89.640000
# 2092 2019-09-25     66.786667
# 2093 2019-09-26     85.533000
# 2094 2019-09-27     64.119000
# 2095 2019-09-28     70.980000
# 2096 2019-09-29     89.277000
# 2097 2019-09-30     70.939000
# 2098 2019-10-01     98.346000
# 2099 2019-10-02     52.554000
# 2100 2019-10-03     66.400000
# 2101 2019-10-04     52.723000
# 2102 2019-10-05     47.580000
# 2103 2019-10-06     67.490000
# 2104 2019-10-07     82.647000
# 2105 2019-10-08     70.860000

# %%
full_date_range = pd.date_range(
    start=daily["datum"].min(),
    end=daily["datum"].max(),
    freq="D"
)

missing_dates = full_date_range.difference(daily["datum"])

print("Number of missing dates:", len(missing_dates))
print(missing_dates[:20])
# Out:
# Number of missing dates: 0
# DatetimeIndex([], dtype='datetime64[us]', freq='D')

# %%
print(weekly.head(5))
# Out:
#         datum  M01AB  M01AE  N02BA   N02BE  N05B  N05C   R03   R06
# 0  01-05-2014  14.00  11.67   21.3  185.95  41.0   0.0  32.0   7.0
# 1  01-12-2014  29.33  12.68   37.9  190.70  88.0   5.0  21.0   7.2
# 2   1/19/2014  30.67  26.34   45.9  218.40  80.0   8.0  29.0  12.0
# 3   1/26/2014  34.00  32.37   31.5  179.60  80.0   8.0  23.0  10.0
# 4  02-02-2014  31.02  23.35   20.7  159.88  84.0  12.0  29.0  12.0

# %%
print(weekly.tail(5))
# Out:
#           datum  M01AB   M01AE  N02BA    N02BE  N05B  N05C        R03    R06
# 297   9/15/2019  35.51  30.977  19.65  178.375  67.2   5.0  30.000000  30.50
# 298   9/22/2019  46.84  25.396  24.40  248.250  31.2   3.0  26.000000  21.00
# 299   9/29/2019  34.01  22.498  26.60  336.700  61.2   1.0  40.416667  23.10
# 300  10-06-2019  38.70  32.502  19.25  249.450  69.0   5.0  30.000000  12.13
# 301  10/13/2019   7.67   6.237   3.50   95.100  26.0   2.0  12.000000   1.00

# %%
## Checking duplicate date

# %%
print("Duplicate dates:",daily["datum"].duplicated().sum())
print("Rows:",len(daily))
print("Unique dates:",daily["datum"].nunique())
# Out:
# Duplicate dates: 0
# Rows: 2106
# Unique dates: 2106

# %%
## Total demand over time

# %%
plt.figure(figsize=(15,6))

plt.plot(
    daily["datum"],
    daily["total_demand"]
        )
plt.title("Daily Pharmaceutical Demand Over Time")
plt.xlabel("Date")
plt.ylabel("Total  Demand")

plt.grid(True)
plt.show()

# %%
## 7-day rolling average.

# %%
daily["rolling_7"] = (
    daily["total_demand"]
    .rolling(window = 7)
    .mean())

# %%
daily["rolling_7"].head(20)
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6     63.764286
# 7     65.794286
# 8     62.122857
# 9     61.535714
# 10    55.972857
# 11    60.544286
# 12    69.448571
# 13    66.992857
# 14    67.410000
# 15    64.135714
# 16    63.577143
# 17    64.330000
# 18    59.950000
# 19    60.951429
# Name: rolling_7, dtype: float64

# %% [markdown]
# ## Actual vs Rolling demand

# %%
plt.figure(figsize=(15, 6))

plt.plot(
    daily["datum"],
    daily["total_demand"],
    label="Daily Demand",
    alpha=0.5
)

plt.plot(
    daily["datum"],
    daily["rolling_7"],
    label="7-Day Rolling Average"
)

plt.title("Pharmaceutical Demand Trend")
plt.xlabel("Date")
plt.ylabel("Total Demand")

plt.legend()
plt.grid(True)

plt.show()
